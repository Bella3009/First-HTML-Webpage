# %%
# Upload Weather Data

# %%
import pandas as pd

# %%
data = pd.read_csv("TG_STAID000070.txt", skiprows=20, parse_dates=["    DATE"])

# %%
data
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0         70     269 1936-01-01   -158      0
# 1         70     269 1936-01-02   -146      0
# 2         70     269 1936-01-03   -134      0
# 3         70     269 1936-01-04   -143      0
# 4         70     269 1936-01-05   -160      0
# ...      ...     ...        ...    ...    ...
# 31558     70     269 2022-05-27  -9999      9
# 31559     70     269 2022-05-28  -9999      9
# 31560     70     269 2022-05-29  -9999      9
# 31561     70     269 2022-05-30  -9999      9
# 31562     70     269 2022-05-31  -9999      9
#
# [31563 rows x 5 columns]

# %% [markdown]
# ## Show first rows of Data

# %%
data[0:11]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 0      70     269 1936-01-01   -158      0
# 1      70     269 1936-01-02   -146      0
# 2      70     269 1936-01-03   -134      0
# 3      70     269 1936-01-04   -143      0
# 4      70     269 1936-01-05   -160      0
# 5      70     269 1936-01-06   -142      0
# 6      70     269 1936-01-07   -122      0
# 7      70     269 1936-01-08   -126      0
# 8      70     269 1936-01-09   -152      0
# 9      70     269 1936-01-10   -168      0
# 10     70     269 1936-01-11   -136      0

# %% [markdown]
# ## Show certain columns of Data

# %%
data.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
data[["   TG","    DATE"]]
# Out:
#           TG       DATE
# 0       -158 1936-01-01
# 1       -146 1936-01-02
# 2       -134 1936-01-03
# 3       -143 1936-01-04
# 4       -160 1936-01-05
# ...      ...        ...
# 31558  -9999 2022-05-27
# 31559  -9999 2022-05-28
# 31560  -9999 2022-05-29
# 31561  -9999 2022-05-30
# 31562  -9999 2022-05-31
#
# [31563 rows x 2 columns]

# %% [markdown]
# # Simple Statistics and Filtering

# %%
data.loc[data[" Q_TG"] != 9] ["   TG"].mean()/10
# Out:
# 6.825150152614133

# %%
data.loc[data["    DATE"]=="1996-03-31"] ["   TG"].squeeze()/10
# Out:
# -2.8

# %%
# Calculate a New Column

# %%
import numpy as np
data["Temp"] = data["   TG"].mask(data["   TG"] ==-9999, np.nan)

# %%
data["TG"] = data["Temp"] /10

# %%
data
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   Temp    TG
# 0         70     269 1936-01-01   -158      0 -158.0 -15.8
# 1         70     269 1936-01-02   -146      0 -146.0 -14.6
# 2         70     269 1936-01-03   -134      0 -134.0 -13.4
# 3         70     269 1936-01-04   -143      0 -143.0 -14.3
# 4         70     269 1936-01-05   -160      0 -160.0 -16.0
# ...      ...     ...        ...    ...    ...    ...   ...
# 31558     70     269 2022-05-27  -9999      9    NaN   NaN
# 31559     70     269 2022-05-28  -9999      9    NaN   NaN
# 31560     70     269 2022-05-29  -9999      9    NaN   NaN
# 31561     70     269 2022-05-30  -9999      9    NaN   NaN
# 31562     70     269 2022-05-31  -9999      9    NaN   NaN
#
# [31563 rows x 7 columns]

# %%
data.hist("TG")
# Out:
# array([[<AxesSubplot: title={'center': 'TG'}>]], dtype=object)

# %%
data.plot(x = "    DATE", y = "TG", figsize=(15,3))
# Out:
# <AxesSubplot: xlabel='    DATE'>
